# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Input
from sklearn.model_selection import train_test_split
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error
import mlflow
from mlflow.exceptions import RestException
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.backend import clear_session
import pywt

# %% [markdown]
# # Leyendo data y limpiandola

# %%
path_data = f'../sandbox/pepe.csv'
df = pd.read_csv(path_data,header=0)

# %%
#Limpieando la data 

# Convertir "Open time" y "Close time" a datetime y darle formato ISO 8601
df['Open time_date'] = pd.to_datetime(df['Open time'], unit='ms').apply(lambda x: x.isoformat())
df['Close time_date'] = pd.to_datetime(df['Close time'], unit='ms').apply(lambda x: x.isoformat())

#Escalando el valor de el campo Close
df['closex1M'] = df['Close'] * 1000000

# NORMALIZAR LA DATA QUITAR ESA TRASFORMACION

scaler = MinMaxScaler(feature_range=(0, 1))  # O feature_range=(-1, 1)
df['Close_Norm'] = scaler.fit_transform(df['closex1M'].to_numpy().reshape(-1, 1))

# %%
scales = (1,256)

# %%
coefficients, frequencies = pywt.cwt(df.closex1M, scales=np.arange(1, 256), wavelet="mexh")
print(coefficients.shape)
print(frequencies.shape)
# Out:
# (255, 15340)
# (255,)

# %%
coeffs_df = pd.DataFrame(coefficients).transpose()
coeffs_df.columns = coeffs_df.columns.map(str)
coeffs_df['closex1M'] = df['closex1M']
scaler_w = MinMaxScaler(feature_range=(-1, 1)) 
# Normalizar todas las columnas
X_normalized = scaler_w.fit_transform(coeffs_df)

# Convertir el resultado nuevamente en un DataFrame
coeffs_df = pd.DataFrame(X_normalized, columns=coeffs_df.columns)
coeffs_df.shape
# Out:
# (15340, 256)

# %%
coeffs_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.461662 -0.370946 -0.278659 -0.199020 -0.171362 -0.166711 -0.158524
# 1 -0.007581 -0.046946 -0.052455 -0.030703 -0.037447 -0.057355 -0.069812
# 2 -0.162089  0.086289  0.123879  0.114102  0.082187  0.036592  0.012961
# 3 -0.393893  0.017476  0.201648  0.212622  0.168647  0.119912  0.083594
# 4 -0.486516 -0.107787  0.191252  0.253948  0.225596  0.178140  0.144284
#
#           7         8         9  ...       246       247       248       249  \
# 0 -0.146490 -0.127450 -0.108589  ...  0.035841  0.036123  0.032728  0.033332
# 1 -0.069668 -0.060175 -0.051231  ...  0.035863  0.035936  0.032731  0.033536
# 2  0.002694  0.002754  0.011034  ...  0.039276  0.039516  0.035966  0.035899
# 3  0.067249  0.060455  0.062177  ...  0.038218  0.038554  0.035386  0.036996
# 4  0.121230  0.110737  0.115595  ...  0.040550  0.040679  0.037151  0.037374
#
#         250       251       252       253       254  closex1M
# 0  0.032059  0.029367  0.028230  0.027944  0.027370 -0.816828
# 1  0.031938  0.028469  0.027216  0.027805  0.025976 -0.795979
# 2  0.035407  0.033047  0.032095  0.031324  0.029573 -0.783321
# 3  0.036580  0.032600  0.031563  0.031347  0.029390 -0.807148
# 4  0.036565  0.033763  0.032538  0.032406  0.031840 -0.797468
#
# [5 rows x 256 columns]

# %% [markdown]
# # Conexion a Mlflow server
# tambien se crean las ejecuciones necesarias

# %%
remote_server_uri = "http://34.58.215.162:8080/"  # set to your server URI
mlflow.set_tracking_uri(remote_server_uri)

#Creacion o identificacion del experimento 
try:
    experiment_name = 'WV_PLUS_MODEL' #Puede ser cualquiera siempre y cuando no se troque con otro
    experiment_id = (mlflow
                        .create_experiment(name=experiment_name
                                            ,tags={'created_by':'Victor Moreno'})) #importante poner el nombre de quien lo crea
except RestException as r:
    print(r)
    experiment = mlflow.get_experiment_by_name(experiment_name)
    print('Full name',experiment.name)
    experiment_id = experiment.experiment_id
# Out:
# RESOURCE_ALREADY_EXISTS: Experiment 'WV_PLUS_MODEL' already exists.
# Full name WV_PLUS_MODEL

# %% [markdown]
# ## Creando la ejecucion

# %%
nombre_hijo = 'LSTM'
nombre_nieto = 'WVC_1-512'

with mlflow.start_run(experiment_id=experiment_id
                      #,run_name='PEPE'# El nombre se coloca solo la primera vez
                      ,run_id='963dc6ab70094271baf0f267a4e80566'
                      ) as run_parent:
    with mlflow.start_run(experiment_id=experiment_id
                          #,run_name= nombre_hijo # Acá se ponne el nombre de la ejecución
                          , run_id = "713eabcc56814f22b75907f71cf6ef28"
                          ,nested=True) as run_child:
        with mlflow.start_run(experiment_id=experiment_id
        , run_name= nombre_nieto
        , nested= True) as run_grandchild:
            print(f'Run creada para {nombre_nieto} con run_id',run_grandchild.info.run_id)
        print(f'Run creada para {nombre_hijo} con run_id',run_child.info.run_id)
# Out:
# Run creada para WVC_1-512 con run_id ee2a6339d64d4c589f7d86f29255345e
# 🏃 View run WVC_1-512 at: http://34.58.215.162:8080/#/experiments/526235632293394123/runs/ee2a6339d64d4c589f7d86f29255345e
# 🧪 View experiment at: http://34.58.215.162:8080/#/experiments/526235632293394123
# Run creada para LSTM con run_id 713eabcc56814f22b75907f71cf6ef28
# 🏃 View run LSTM at: http://34.58.215.162:8080/#/experiments/526235632293394123/runs/713eabcc56814f22b75907f71cf6ef28
# 🧪 View experiment at: http://34.58.215.162:8080/#/experiments/526235632293394123
# 🏃 View run PEPE at: http://34.58.215.162:8080/#/experiments/526235632293394123/runs/963dc6ab70094271baf0f267a4e80566
# 🧪 View experiment at: http://34.58.215.162:8080/#/experiments/526235632293394123

# %%
# Ejemplo
#mlflow.log_artifact(wave_img_path,run_id=run_child.info.run_id,artifact_path='resultados')

# %% [markdown]
# # Entrenamiento

# %% [markdown]
# ## Preparacion de la data

# %%
coeffs_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.461662 -0.370946 -0.278659 -0.199020 -0.171362 -0.166711 -0.158524
# 1 -0.007581 -0.046946 -0.052455 -0.030703 -0.037447 -0.057355 -0.069812
# 2 -0.162089  0.086289  0.123879  0.114102  0.082187  0.036592  0.012961
# 3 -0.393893  0.017476  0.201648  0.212622  0.168647  0.119912  0.083594
# 4 -0.486516 -0.107787  0.191252  0.253948  0.225596  0.178140  0.144284
#
#           7         8         9  ...       246       247       248       249  \
# 0 -0.146490 -0.127450 -0.108589  ...  0.035841  0.036123  0.032728  0.033332
# 1 -0.069668 -0.060175 -0.051231  ...  0.035863  0.035936  0.032731  0.033536
# 2  0.002694  0.002754  0.011034  ...  0.039276  0.039516  0.035966  0.035899
# 3  0.067249  0.060455  0.062177  ...  0.038218  0.038554  0.035386  0.036996
# 4  0.121230  0.110737  0.115595  ...  0.040550  0.040679  0.037151  0.037374
#
#         250       251       252       253       254  closex1M
# 0  0.032059  0.029367  0.028230  0.027944  0.027370 -0.816828
# 1  0.031938  0.028469  0.027216  0.027805  0.025976 -0.795979
# 2  0.035407  0.033047  0.032095  0.031324  0.029573 -0.783321
# 3  0.036580  0.032600  0.031563  0.031347  0.029390 -0.807148
# 4  0.036565  0.033763  0.032538  0.032406  0.031840 -0.797468
#
# [5 rows x 256 columns]

# %%
df_train = coeffs_df.copy()
# Crear secuencias para la LSTM
timesteps = 24
X, y = [], []
for i in range(len(df_train) - timesteps):
    X.append(df_train[i:i+timesteps])
    y.append(df.Close_Norm[i+timesteps])  # Valor futuro
X, y = np.array(X), np.array(y)

# %%
df_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.461662 -0.370946 -0.278659 -0.199020 -0.171362 -0.166711 -0.158524
# 1 -0.007581 -0.046946 -0.052455 -0.030703 -0.037447 -0.057355 -0.069812
# 2 -0.162089  0.086289  0.123879  0.114102  0.082187  0.036592  0.012961
# 3 -0.393893  0.017476  0.201648  0.212622  0.168647  0.119912  0.083594
# 4 -0.486516 -0.107787  0.191252  0.253948  0.225596  0.178140  0.144284
#
#           7         8         9  ...       246       247       248       249  \
# 0 -0.146490 -0.127450 -0.108589  ...  0.035841  0.036123  0.032728  0.033332
# 1 -0.069668 -0.060175 -0.051231  ...  0.035863  0.035936  0.032731  0.033536
# 2  0.002694  0.002754  0.011034  ...  0.039276  0.039516  0.035966  0.035899
# 3  0.067249  0.060455  0.062177  ...  0.038218  0.038554  0.035386  0.036996
# 4  0.121230  0.110737  0.115595  ...  0.040550  0.040679  0.037151  0.037374
#
#         250       251       252       253       254  closex1M
# 0  0.032059  0.029367  0.028230  0.027944  0.027370 -0.816828
# 1  0.031938  0.028469  0.027216  0.027805  0.025976 -0.795979
# 2  0.035407  0.033047  0.032095  0.031324  0.029573 -0.783321
# 3  0.036580  0.032600  0.031563  0.031347  0.029390 -0.807148
# 4  0.036565  0.033763  0.032538  0.032406  0.031840 -0.797468
#
# [5 rows x 256 columns]

# %%
window_size = 24
#X, Y = create_sequences(df_train,window_size=window_size,target_col='closex1M')

#X = X.reshape(X.shape[0],X.shape[1])

#Y = Y.reshape(-1,1)

#Espliteando la data
X_train, X_vt, y_train, y_vt = train_test_split(X, y, test_size=0.3, shuffle=False)

x_val, x_test, y_val, y_test = train_test_split(X_vt,y_vt,test_size=0.1, shuffle=False)


# Reshape para que sea compatible con LSTM (samples, time steps, features)
#X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
#X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Creando modelo

# %%
capas =  [('LSTM',50),('LSTM',100),('LSTM',150),('DENSE',1)]
#fn_activation_by_layer = #['relu','relu','relu','relu']
epochs = 45
batch_size = 128
loss_metric = 'mse'
model_metrics = ['mae']
model_result_path = 'model_results.html'
optimizer = 'adam'

# %%
scales[1]
# Out:
# 256

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
clear_session()
# Definición del modelo
model = Sequential()

# 🔹 Capa convolucional 1D
model.add(Conv1D(filters=128, kernel_size=3, activation='tanh', input_shape=(window_size, df_train.shape[1])))
model.add(MaxPooling1D(pool_size=2))

# 🔹 Segunda capa convolucional (opcional)
model.add(Conv1D(filters=64, kernel_size=3, activation='tanh'))
model.add(MaxPooling1D(pool_size=2))

# 🔹 Capa LSTM para capturar patrones a largo plazo
model.add(LSTM(units=25, return_sequences=True))
model.add(LSTM(units=100, return_sequences=True))

model.add(LSTM(units=150, return_sequences=False))

# 🔹 Capas densas para la predicción final
model.add(Dense(200, activation='relu'))

model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='linear'))  # Salida para regresión

# Compilación del modelo
model.compile(optimizer = Adam(learning_rate=0.000001), loss='mse', metrics=['mae'])

# Resumen del modelo
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 22, 128)        │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 11, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 9, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 4, 25)          │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 4, 100)         │        50,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │        30,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 383,473 (1.46 MB)
#  Trainable params: 383,473 (1.46 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Limpiamos el grafo computacional
clear_session()

# Crear el modelo secuencial
model = Sequential()

# Construcción dinámica de la red neuronal
for i, (tipo, unidades) in enumerate(capas):
    if tipo == 'LSTM':
        # Primera capa LSTM necesita input_shape
        if i == 0:
            model.add(LSTM(units=unidades,activation='tanh', return_sequences=True, input_shape=(window_size, df_train.shape[1])))
        # Última capa LSTM antes de Dense no necesita return_sequences
        elif i == len(capas) - 2:
            model.add(LSTM(units=unidades, activation='tanh',return_sequences=False))
        else:
            model.add(LSTM(units=unidades,activation='tanh', return_sequences=True))

    elif tipo == 'DENSE':  # Capa densa final
        model.add(Dense(units=unidades, activation='linear'))

# Compilar el modelo
model.compile(optimizer = Adam(learning_rate=0.0001) , loss=loss_metric, metrics=model_metrics)

# Mostrar el resumen del modelo
model.summary()
# Out:
# c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 24, 50)         │       112,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 24, 100)        │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           151 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 323,751 (1.24 MB)
#  Trainable params: 323,751 (1.24 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
coeffs_df.shape
# Out:
# (15340, 512)

# %%
X_train.shape
# Out:
# (10721, 24, 512)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# 🔹 EarlyStopping: Detiene el entrenamiento cuando la métrica no mejora
early_stopping = EarlyStopping(
    monitor='val_loss',  # Métrica a monitorear
    patience=10,         # Número de épocas sin mejora antes de detener el entrenamiento
    restore_best_weights=True  # Restaura los pesos de la mejor época
)

# 🔹 ReduceLROnPlateau: Reduce la tasa de aprendizaje cuando la métrica se estanca
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Métrica a monitorear
    factor=0.5,          # Factor por el cual se reducirá la tasa de aprendizaje
    patience=5,          # Número de épocas sin mejora antes de reducir el learning rate
    min_lr=1e-14         # Tasa de aprendizaje mínima permitida
)

# %%
#Entrenando el modelo
history = model.fit(X_train,
                    y_train,
                    epochs=2000,
                    batch_size=batch_size,
                    callbacks=[early_stopping,reduce_lr],
                    validation_data=(x_val, y_val),
                    verbose=1
                    )
# Out:
# Epoch 1/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - loss: 0.0431 - mae: 0.1321 - val_loss: 0.2643 - val_mae: 0.4674 - learning_rate: 1.0000e-06
# Epoch 2/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0423 - mae: 0.1282 - val_loss: 0.2593 - val_mae: 0.4621 - learning_rate: 1.0000e-06
# Epoch 3/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0408 - mae: 0.1233 - val_loss: 0.2545 - val_mae: 0.4567 - learning_rate: 1.0000e-06
# Epoch 4/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0389 - mae: 0.1164 - val_loss: 0.2497 - val_mae: 0.4515 - learning_rate: 1.0000e-06
# Epoch 5/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0379 - mae: 0.1143 - val_loss: 0.2452 - val_mae: 0.4466 - learning_rate: 1.0000e-06
# Epoch 6/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0369 - mae: 0.1120 - val_loss: 0.2408 - val_mae: 0.4418 - learning_rate: 1.0000e-06
# Epoch 7/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0355 - mae: 0.1083 - val_loss: 0.2363 - val_mae: 0.4368 - learning_rate: 1.0000e-06
# Epoch 8/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0350 - mae: 0.1088 - val_loss: 0.2317 - val_mae: 0.4316 - learning_rate: 1.0000e-06
# Epoch 9/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0342 - mae: 0.1106 - val_loss: 0.2269 - val_mae: 0.4261 - learning_rate: 1.0000e-06
# Epoch 10/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0330 - mae: 0.1112 - val_loss: 0.2218 - val_mae: 0.4203 - learning_rate: 1.0000e-06
# Epoch 11/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0314 - mae: 0.1113 - val_loss: 0.2165 - val_mae: 0.4143 - learning_rate: 1.0000e-06
# Epoch 12/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.0295 - mae: 0.1107 - val_loss: 0.2113 - val_mae: 0.4082 - learning_rate: 1.0000e-06
# Epoch 13/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0300 - mae: 0.1158 - val_loss: 0.2060 - val_mae: 0.4021 - learning_rate: 1.0000e-06
# Epoch 14/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0285 - mae: 0.1161 - val_loss: 0.2006 - val_mae: 0.3958 - learning_rate: 1.0000e-06
# Epoch 15/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0278 - mae: 0.1179 - val_loss: 0.1952 - val_mae: 0.3896 - learning_rate: 1.0000e-06
# Epoch 16/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0269 - mae: 0.1195 - val_loss: 0.1901 - val_mae: 0.3836 - learning_rate: 1.0000e-06
# Epoch 17/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0257 - mae: 0.1189 - val_loss: 0.1851 - val_mae: 0.3777 - learning_rate: 1.0000e-06
# Epoch 18/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0258 - mae: 0.1220 - val_loss: 0.1802 - val_mae: 0.3721 - learning_rate: 1.0000e-06
# Epoch 19/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0252 - mae: 0.1225 - val_loss: 0.1756 - val_mae: 0.3669 - learning_rate: 1.0000e-06
# Epoch 20/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0248 - mae: 0.1237 - val_loss: 0.1714 - val_mae: 0.3620 - learning_rate: 1.0000e-06
# Epoch 21/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0240 - mae: 0.1232 - val_loss: 0.1673 - val_mae: 0.3574 - learning_rate: 1.0000e-06
# Epoch 22/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0236 - mae: 0.1234 - val_loss: 0.1636 - val_mae: 0.3533 - learning_rate: 1.0000e-06
# Epoch 23/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0222 - mae: 0.1203 - val_loss: 0.1600 - val_mae: 0.3494 - learning_rate: 1.0000e-06
# Epoch 24/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0219 - mae: 0.1199 - val_loss: 0.1564 - val_mae: 0.3453 - learning_rate: 1.0000e-06
# Epoch 25/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0214 - mae: 0.1190 - val_loss: 0.1530 - val_mae: 0.3415 - learning_rate: 1.0000e-06
# Epoch 26/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0211 - mae: 0.1186 - val_loss: 0.1495 - val_mae: 0.3376 - learning_rate: 1.0000e-06
# Epoch 27/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0202 - mae: 0.1161 - val_loss: 0.1462 - val_mae: 0.3338 - learning_rate: 1.0000e-06
# Epoch 28/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0198 - mae: 0.1150 - val_loss: 0.1428 - val_mae: 0.3299 - learning_rate: 1.0000e-06
# Epoch 29/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0193 - mae: 0.1133 - val_loss: 0.1398 - val_mae: 0.3264 - learning_rate: 1.0000e-06
# Epoch 30/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0192 - mae: 0.1134 - val_loss: 0.1366 - val_mae: 0.3225 - learning_rate: 1.0000e-06
# Epoch 31/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0180 - mae: 0.1090 - val_loss: 0.1336 - val_mae: 0.3188 - learning_rate: 1.0000e-06
# Epoch 32/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0173 - mae: 0.1064 - val_loss: 0.1304 - val_mae: 0.3148 - learning_rate: 1.0000e-06
# Epoch 33/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0168 - mae: 0.1046 - val_loss: 0.1273 - val_mae: 0.3106 - learning_rate: 1.0000e-06
# Epoch 34/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0163 - mae: 0.1028 - val_loss: 0.1241 - val_mae: 0.3063 - learning_rate: 1.0000e-06
# Epoch 35/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0163 - mae: 0.1025 - val_loss: 0.1210 - val_mae: 0.3020 - learning_rate: 1.0000e-06
# Epoch 36/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0155 - mae: 0.0997 - val_loss: 0.1182 - val_mae: 0.2979 - learning_rate: 1.0000e-06
# Epoch 37/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0152 - mae: 0.0985 - val_loss: 0.1153 - val_mae: 0.2937 - learning_rate: 1.0000e-06
# Epoch 38/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0147 - mae: 0.0966 - val_loss: 0.1125 - val_mae: 0.2894 - learning_rate: 1.0000e-06
# Epoch 39/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0139 - mae: 0.0936 - val_loss: 0.1099 - val_mae: 0.2853 - learning_rate: 1.0000e-06
# Epoch 40/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0142 - mae: 0.0942 - val_loss: 0.1075 - val_mae: 0.2816 - learning_rate: 1.0000e-06
# Epoch 41/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0140 - mae: 0.0929 - val_loss: 0.1052 - val_mae: 0.2777 - learning_rate: 1.0000e-06
# Epoch 42/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0130 - mae: 0.0888 - val_loss: 0.1030 - val_mae: 0.2741 - learning_rate: 1.0000e-06
# Epoch 43/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0128 - mae: 0.0873 - val_loss: 0.1008 - val_mae: 0.2702 - learning_rate: 1.0000e-06
# Epoch 44/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0125 - mae: 0.0851 - val_loss: 0.0985 - val_mae: 0.2661 - learning_rate: 1.0000e-06
# Epoch 45/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0123 - mae: 0.0836 - val_loss: 0.0964 - val_mae: 0.2623 - learning_rate: 1.0000e-06
# Epoch 46/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0122 - mae: 0.0826 - val_loss: 0.0943 - val_mae: 0.2585 - learning_rate: 1.0000e-06
# Epoch 47/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0117 - mae: 0.0803 - val_loss: 0.0924 - val_mae: 0.2548 - learning_rate: 1.0000e-06
# Epoch 48/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0114 - mae: 0.0790 - val_loss: 0.0904 - val_mae: 0.2508 - learning_rate: 1.0000e-06
# Epoch 49/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0115 - mae: 0.0788 - val_loss: 0.0886 - val_mae: 0.2473 - learning_rate: 1.0000e-06
# Epoch 50/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0109 - mae: 0.0762 - val_loss: 0.0866 - val_mae: 0.2434 - learning_rate: 1.0000e-06
# Epoch 51/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0108 - mae: 0.0756 - val_loss: 0.0853 - val_mae: 0.2407 - learning_rate: 1.0000e-06
# Epoch 52/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0108 - mae: 0.0745 - val_loss: 0.0838 - val_mae: 0.2377 - learning_rate: 1.0000e-06
# Epoch 53/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0103 - mae: 0.0722 - val_loss: 0.0823 - val_mae: 0.2349 - learning_rate: 1.0000e-06
# Epoch 54/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0106 - mae: 0.0723 - val_loss: 0.0812 - val_mae: 0.2328 - learning_rate: 1.0000e-06
# Epoch 55/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0106 - mae: 0.0722 - val_loss: 0.0798 - val_mae: 0.2303 - learning_rate: 1.0000e-06
# Epoch 56/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0103 - mae: 0.0709 - val_loss: 0.0791 - val_mae: 0.2289 - learning_rate: 1.0000e-06
# Epoch 57/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0103 - mae: 0.0701 - val_loss: 0.0778 - val_mae: 0.2267 - learning_rate: 1.0000e-06
# Epoch 58/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0099 - mae: 0.0681 - val_loss: 0.0767 - val_mae: 0.2246 - learning_rate: 1.0000e-06
# Epoch 59/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0100 - mae: 0.0686 - val_loss: 0.0758 - val_mae: 0.2231 - learning_rate: 1.0000e-06
# Epoch 60/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0099 - mae: 0.0683 - val_loss: 0.0750 - val_mae: 0.2217 - learning_rate: 1.0000e-06
# Epoch 61/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0097 - mae: 0.0665 - val_loss: 0.0740 - val_mae: 0.2202 - learning_rate: 1.0000e-06
# Epoch 62/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0093 - mae: 0.0646 - val_loss: 0.0729 - val_mae: 0.2182 - learning_rate: 1.0000e-06
# Epoch 63/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0096 - mae: 0.0660 - val_loss: 0.0725 - val_mae: 0.2178 - learning_rate: 1.0000e-06
# Epoch 64/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0090 - mae: 0.0636 - val_loss: 0.0715 - val_mae: 0.2159 - learning_rate: 1.0000e-06
# Epoch 65/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0092 - mae: 0.0652 - val_loss: 0.0711 - val_mae: 0.2157 - learning_rate: 1.0000e-06
# Epoch 66/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0091 - mae: 0.0640 - val_loss: 0.0702 - val_mae: 0.2141 - learning_rate: 1.0000e-06
# Epoch 67/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0089 - mae: 0.0630 - val_loss: 0.0694 - val_mae: 0.2130 - learning_rate: 1.0000e-06
# Epoch 68/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0087 - mae: 0.0621 - val_loss: 0.0689 - val_mae: 0.2123 - learning_rate: 1.0000e-06
# Epoch 69/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0089 - mae: 0.0630 - val_loss: 0.0682 - val_mae: 0.2115 - learning_rate: 1.0000e-06
# Epoch 70/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0084 - mae: 0.0599 - val_loss: 0.0674 - val_mae: 0.2100 - learning_rate: 1.0000e-06
# Epoch 71/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0084 - mae: 0.0606 - val_loss: 0.0665 - val_mae: 0.2087 - learning_rate: 1.0000e-06
# Epoch 72/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0078 - mae: 0.0581 - val_loss: 0.0657 - val_mae: 0.2071 - learning_rate: 1.0000e-06
# Epoch 73/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0079 - mae: 0.0587 - val_loss: 0.0652 - val_mae: 0.2065 - learning_rate: 1.0000e-06
# Epoch 74/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0079 - mae: 0.0587 - val_loss: 0.0647 - val_mae: 0.2057 - learning_rate: 1.0000e-06
# Epoch 75/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0073 - mae: 0.0553 - val_loss: 0.0641 - val_mae: 0.2048 - learning_rate: 1.0000e-06
# Epoch 76/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0074 - mae: 0.0562 - val_loss: 0.0632 - val_mae: 0.2032 - learning_rate: 1.0000e-06
# Epoch 77/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0073 - mae: 0.0564 - val_loss: 0.0626 - val_mae: 0.2024 - learning_rate: 1.0000e-06
# Epoch 78/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0073 - mae: 0.0552 - val_loss: 0.0612 - val_mae: 0.1997 - learning_rate: 1.0000e-06
# Epoch 79/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0072 - mae: 0.0558 - val_loss: 0.0610 - val_mae: 0.1997 - learning_rate: 1.0000e-06
# Epoch 80/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0069 - mae: 0.0538 - val_loss: 0.0600 - val_mae: 0.1980 - learning_rate: 1.0000e-06
# Epoch 81/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0065 - mae: 0.0519 - val_loss: 0.0594 - val_mae: 0.1969 - learning_rate: 1.0000e-06
# Epoch 82/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0066 - mae: 0.0524 - val_loss: 0.0586 - val_mae: 0.1954 - learning_rate: 1.0000e-06
# Epoch 83/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0063 - mae: 0.0512 - val_loss: 0.0577 - val_mae: 0.1939 - learning_rate: 1.0000e-06
# Epoch 84/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0063 - mae: 0.0513 - val_loss: 0.0570 - val_mae: 0.1925 - learning_rate: 1.0000e-06
# Epoch 85/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0061 - mae: 0.0505 - val_loss: 0.0562 - val_mae: 0.1911 - learning_rate: 1.0000e-06
# Epoch 86/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0058 - mae: 0.0487 - val_loss: 0.0549 - val_mae: 0.1884 - learning_rate: 1.0000e-06
# Epoch 87/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0057 - mae: 0.0485 - val_loss: 0.0540 - val_mae: 0.1867 - learning_rate: 1.0000e-06
# Epoch 88/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0054 - mae: 0.0469 - val_loss: 0.0529 - val_mae: 0.1845 - learning_rate: 1.0000e-06
# Epoch 89/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0051 - mae: 0.0454 - val_loss: 0.0519 - val_mae: 0.1823 - learning_rate: 1.0000e-06
# Epoch 90/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0050 - mae: 0.0449 - val_loss: 0.0512 - val_mae: 0.1810 - learning_rate: 1.0000e-06
# Epoch 91/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0048 - mae: 0.0438 - val_loss: 0.0500 - val_mae: 0.1784 - learning_rate: 1.0000e-06
# Epoch 92/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0047 - mae: 0.0436 - val_loss: 0.0492 - val_mae: 0.1769 - learning_rate: 1.0000e-06
# Epoch 93/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0043 - mae: 0.0418 - val_loss: 0.0478 - val_mae: 0.1735 - learning_rate: 1.0000e-06
# Epoch 94/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0042 - mae: 0.0417 - val_loss: 0.0471 - val_mae: 0.1722 - learning_rate: 1.0000e-06
# Epoch 95/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0042 - mae: 0.0407 - val_loss: 0.0458 - val_mae: 0.1692 - learning_rate: 1.0000e-06
# Epoch 96/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0039 - mae: 0.0394 - val_loss: 0.0447 - val_mae: 0.1667 - learning_rate: 1.0000e-06
# Epoch 97/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0036 - mae: 0.0376 - val_loss: 0.0437 - val_mae: 0.1645 - learning_rate: 1.0000e-06
# Epoch 98/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0035 - mae: 0.0371 - val_loss: 0.0429 - val_mae: 0.1625 - learning_rate: 1.0000e-06
# Epoch 99/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0033 - mae: 0.0356 - val_loss: 0.0413 - val_mae: 0.1585 - learning_rate: 1.0000e-06
# Epoch 100/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0031 - mae: 0.0345 - val_loss: 0.0403 - val_mae: 0.1565 - learning_rate: 1.0000e-06
# Epoch 101/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0029 - mae: 0.0330 - val_loss: 0.0389 - val_mae: 0.1527 - learning_rate: 1.0000e-06
# Epoch 102/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0028 - mae: 0.0330 - val_loss: 0.0381 - val_mae: 0.1509 - learning_rate: 1.0000e-06
# Epoch 103/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0026 - mae: 0.0316 - val_loss: 0.0370 - val_mae: 0.1480 - learning_rate: 1.0000e-06
# Epoch 104/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0027 - mae: 0.0314 - val_loss: 0.0356 - val_mae: 0.1443 - learning_rate: 1.0000e-06
# Epoch 105/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0024 - mae: 0.0298 - val_loss: 0.0348 - val_mae: 0.1422 - learning_rate: 1.0000e-06
# Epoch 106/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0021 - mae: 0.0278 - val_loss: 0.0337 - val_mae: 0.1392 - learning_rate: 1.0000e-06
# Epoch 107/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0021 - mae: 0.0272 - val_loss: 0.0330 - val_mae: 0.1373 - learning_rate: 1.0000e-06
# Epoch 108/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0018 - mae: 0.0252 - val_loss: 0.0319 - val_mae: 0.1343 - learning_rate: 1.0000e-06
# Epoch 109/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0017 - mae: 0.0249 - val_loss: 0.0306 - val_mae: 0.1305 - learning_rate: 1.0000e-06
# Epoch 110/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0017 - mae: 0.0241 - val_loss: 0.0298 - val_mae: 0.1285 - learning_rate: 1.0000e-06
# Epoch 111/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0015 - mae: 0.0230 - val_loss: 0.0287 - val_mae: 0.1249 - learning_rate: 1.0000e-06
# Epoch 112/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0013 - mae: 0.0217 - val_loss: 0.0280 - val_mae: 0.1230 - learning_rate: 1.0000e-06
# Epoch 113/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0012 - mae: 0.0207 - val_loss: 0.0271 - val_mae: 0.1200 - learning_rate: 1.0000e-06
# Epoch 114/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0013 - mae: 0.0210 - val_loss: 0.0267 - val_mae: 0.1193 - learning_rate: 1.0000e-06
# Epoch 115/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0011 - mae: 0.0200 - val_loss: 0.0257 - val_mae: 0.1160 - learning_rate: 1.0000e-06
# Epoch 116/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0011 - mae: 0.0195 - val_loss: 0.0250 - val_mae: 0.1139 - learning_rate: 1.0000e-06
# Epoch 117/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.8167e-04 - mae: 0.0185 - val_loss: 0.0244 - val_mae: 0.1120 - learning_rate: 1.0000e-06
# Epoch 118/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 8.7518e-04 - mae: 0.0175 - val_loss: 0.0236 - val_mae: 0.1091 - learning_rate: 1.0000e-06
# Epoch 119/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 8.1271e-04 - mae: 0.0168 - val_loss: 0.0229 - val_mae: 0.1071 - learning_rate: 1.0000e-06
# Epoch 120/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 7.7564e-04 - mae: 0.0166 - val_loss: 0.0220 - val_mae: 0.1039 - learning_rate: 1.0000e-06
# Epoch 121/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 7.4444e-04 - mae: 0.0161 - val_loss: 0.0219 - val_mae: 0.1041 - learning_rate: 1.0000e-06
# Epoch 122/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 6.5757e-04 - mae: 0.0153 - val_loss: 0.0212 - val_mae: 0.1014 - learning_rate: 1.0000e-06
# Epoch 123/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 6.3049e-04 - mae: 0.0150 - val_loss: 0.0207 - val_mae: 0.0994 - learning_rate: 1.0000e-06
# Epoch 124/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 5.6974e-04 - mae: 0.0142 - val_loss: 0.0200 - val_mae: 0.0975 - learning_rate: 1.0000e-06
# Epoch 125/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.5977e-04 - mae: 0.0141 - val_loss: 0.0197 - val_mae: 0.0964 - learning_rate: 1.0000e-06
# Epoch 126/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 5.6647e-04 - mae: 0.0142 - val_loss: 0.0193 - val_mae: 0.0950 - learning_rate: 1.0000e-06
# Epoch 127/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.0064e-04 - mae: 0.0133 - val_loss: 0.0188 - val_mae: 0.0932 - learning_rate: 1.0000e-06
# Epoch 128/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 4.5585e-04 - mae: 0.0126 - val_loss: 0.0187 - val_mae: 0.0934 - learning_rate: 1.0000e-06
# Epoch 129/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.4974e-04 - mae: 0.0126 - val_loss: 0.0183 - val_mae: 0.0916 - learning_rate: 1.0000e-06
# Epoch 130/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.4294e-04 - mae: 0.0125 - val_loss: 0.0180 - val_mae: 0.0911 - learning_rate: 1.0000e-06
# Epoch 131/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 4.0678e-04 - mae: 0.0121 - val_loss: 0.0178 - val_mae: 0.0901 - learning_rate: 1.0000e-06
# Epoch 132/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 3.8130e-04 - mae: 0.0117 - val_loss: 0.0173 - val_mae: 0.0884 - learning_rate: 1.0000e-06
# Epoch 133/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.7061e-04 - mae: 0.0115 - val_loss: 0.0171 - val_mae: 0.0880 - learning_rate: 1.0000e-06
# Epoch 134/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.6311e-04 - mae: 0.0114 - val_loss: 0.0168 - val_mae: 0.0872 - learning_rate: 1.0000e-06
# Epoch 135/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.4347e-04 - mae: 0.0110 - val_loss: 0.0167 - val_mae: 0.0865 - learning_rate: 1.0000e-06
# Epoch 136/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.5388e-04 - mae: 0.0113 - val_loss: 0.0164 - val_mae: 0.0858 - learning_rate: 1.0000e-06
# Epoch 137/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.2417e-04 - mae: 0.0108 - val_loss: 0.0161 - val_mae: 0.0848 - learning_rate: 1.0000e-06
# Epoch 138/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.2702e-04 - mae: 0.0107 - val_loss: 0.0158 - val_mae: 0.0842 - learning_rate: 1.0000e-06
# Epoch 139/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 3.0012e-04 - mae: 0.0102 - val_loss: 0.0158 - val_mae: 0.0840 - learning_rate: 1.0000e-06
# Epoch 140/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.9337e-04 - mae: 0.0102 - val_loss: 0.0156 - val_mae: 0.0832 - learning_rate: 1.0000e-06
# Epoch 141/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.8282e-04 - mae: 0.0100 - val_loss: 0.0154 - val_mae: 0.0828 - learning_rate: 1.0000e-06
# Epoch 142/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.6606e-04 - mae: 0.0098 - val_loss: 0.0152 - val_mae: 0.0818 - learning_rate: 1.0000e-06
# Epoch 143/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.6833e-04 - mae: 0.0096 - val_loss: 0.0153 - val_mae: 0.0823 - learning_rate: 1.0000e-06
# Epoch 144/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.5731e-04 - mae: 0.0096 - val_loss: 0.0150 - val_mae: 0.0814 - learning_rate: 1.0000e-06
# Epoch 145/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.4470e-04 - mae: 0.0092 - val_loss: 0.0148 - val_mae: 0.0807 - learning_rate: 1.0000e-06
# Epoch 146/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.4065e-04 - mae: 0.0093 - val_loss: 0.0147 - val_mae: 0.0805 - learning_rate: 1.0000e-06
# Epoch 147/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.3335e-04 - mae: 0.0091 - val_loss: 0.0145 - val_mae: 0.0800 - learning_rate: 1.0000e-06
# Epoch 148/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.3002e-04 - mae: 0.0090 - val_loss: 0.0144 - val_mae: 0.0799 - learning_rate: 1.0000e-06
# Epoch 149/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 2.3074e-04 - mae: 0.0091 - val_loss: 0.0143 - val_mae: 0.0793 - learning_rate: 1.0000e-06
# Epoch 150/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.1497e-04 - mae: 0.0088 - val_loss: 0.0140 - val_mae: 0.0780 - learning_rate: 1.0000e-06
# Epoch 151/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.1387e-04 - mae: 0.0086 - val_loss: 0.0142 - val_mae: 0.0789 - learning_rate: 1.0000e-06
# Epoch 152/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.0974e-04 - mae: 0.0086 - val_loss: 0.0139 - val_mae: 0.0781 - learning_rate: 1.0000e-06
# Epoch 153/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 2.0409e-04 - mae: 0.0085 - val_loss: 0.0139 - val_mae: 0.0779 - learning_rate: 1.0000e-06
# Epoch 154/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.9699e-04 - mae: 0.0083 - val_loss: 0.0138 - val_mae: 0.0779 - learning_rate: 1.0000e-06
# Epoch 155/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.9188e-04 - mae: 0.0082 - val_loss: 0.0137 - val_mae: 0.0775 - learning_rate: 1.0000e-06
# Epoch 156/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.8950e-04 - mae: 0.0082 - val_loss: 0.0137 - val_mae: 0.0775 - learning_rate: 1.0000e-06
# Epoch 157/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.8371e-04 - mae: 0.0081 - val_loss: 0.0135 - val_mae: 0.0770 - learning_rate: 1.0000e-06
# Epoch 158/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.8393e-04 - mae: 0.0081 - val_loss: 0.0133 - val_mae: 0.0762 - learning_rate: 1.0000e-06
# Epoch 159/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.7950e-04 - mae: 0.0081 - val_loss: 0.0134 - val_mae: 0.0763 - learning_rate: 1.0000e-06
# Epoch 160/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.7373e-04 - mae: 0.0078 - val_loss: 0.0133 - val_mae: 0.0764 - learning_rate: 1.0000e-06
# Epoch 161/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1.7558e-04 - mae: 0.0079 - val_loss: 0.0132 - val_mae: 0.0760 - learning_rate: 1.0000e-06
# Epoch 162/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.6340e-04 - mae: 0.0075 - val_loss: 0.0132 - val_mae: 0.0757 - learning_rate: 1.0000e-06
# Epoch 163/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.6727e-04 - mae: 0.0077 - val_loss: 0.0131 - val_mae: 0.0756 - learning_rate: 1.0000e-06
# Epoch 164/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.6040e-04 - mae: 0.0076 - val_loss: 0.0129 - val_mae: 0.0748 - learning_rate: 1.0000e-06
# Epoch 165/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.5291e-04 - mae: 0.0074 - val_loss: 0.0130 - val_mae: 0.0753 - learning_rate: 1.0000e-06
# Epoch 166/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.5251e-04 - mae: 0.0074 - val_loss: 0.0129 - val_mae: 0.0747 - learning_rate: 1.0000e-06
# Epoch 167/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.5193e-04 - mae: 0.0073 - val_loss: 0.0127 - val_mae: 0.0742 - learning_rate: 1.0000e-06
# Epoch 168/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.5666e-04 - mae: 0.0074 - val_loss: 0.0126 - val_mae: 0.0738 - learning_rate: 1.0000e-06
# Epoch 169/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.5064e-04 - mae: 0.0073 - val_loss: 0.0127 - val_mae: 0.0744 - learning_rate: 1.0000e-06
# Epoch 170/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.4323e-04 - mae: 0.0071 - val_loss: 0.0125 - val_mae: 0.0736 - learning_rate: 1.0000e-06
# Epoch 171/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.3876e-04 - mae: 0.0070 - val_loss: 0.0124 - val_mae: 0.0733 - learning_rate: 1.0000e-06
# Epoch 172/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.3808e-04 - mae: 0.0070 - val_loss: 0.0124 - val_mae: 0.0732 - learning_rate: 1.0000e-06
# Epoch 173/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.3523e-04 - mae: 0.0069 - val_loss: 0.0122 - val_mae: 0.0725 - learning_rate: 1.0000e-06
# Epoch 174/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.3233e-04 - mae: 0.0068 - val_loss: 0.0122 - val_mae: 0.0727 - learning_rate: 1.0000e-06
# Epoch 175/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.2697e-04 - mae: 0.0067 - val_loss: 0.0121 - val_mae: 0.0721 - learning_rate: 1.0000e-06
# Epoch 176/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.3229e-04 - mae: 0.0068 - val_loss: 0.0120 - val_mae: 0.0721 - learning_rate: 1.0000e-06
# Epoch 177/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.3598e-04 - mae: 0.0069 - val_loss: 0.0121 - val_mae: 0.0723 - learning_rate: 1.0000e-06
# Epoch 178/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1.2298e-04 - mae: 0.0065 - val_loss: 0.0120 - val_mae: 0.0717 - learning_rate: 1.0000e-06
# Epoch 179/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.2380e-04 - mae: 0.0066 - val_loss: 0.0120 - val_mae: 0.0720 - learning_rate: 1.0000e-06
# Epoch 180/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.1935e-04 - mae: 0.0066 - val_loss: 0.0121 - val_mae: 0.0721 - learning_rate: 1.0000e-06
# Epoch 181/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1911e-04 - mae: 0.0065 - val_loss: 0.0119 - val_mae: 0.0714 - learning_rate: 5.0000e-07
# Epoch 182/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1416e-04 - mae: 0.0064 - val_loss: 0.0119 - val_mae: 0.0715 - learning_rate: 5.0000e-07
# Epoch 183/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 1.1763e-04 - mae: 0.0064 - val_loss: 0.0118 - val_mae: 0.0711 - learning_rate: 5.0000e-07
# Epoch 184/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1090e-04 - mae: 0.0063 - val_loss: 0.0118 - val_mae: 0.0713 - learning_rate: 5.0000e-07
# Epoch 185/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0893e-04 - mae: 0.0062 - val_loss: 0.0117 - val_mae: 0.0711 - learning_rate: 5.0000e-07
# Epoch 186/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1740e-04 - mae: 0.0065 - val_loss: 0.0117 - val_mae: 0.0708 - learning_rate: 5.0000e-07
# Epoch 187/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1312e-04 - mae: 0.0063 - val_loss: 0.0117 - val_mae: 0.0710 - learning_rate: 5.0000e-07
# Epoch 188/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1067e-04 - mae: 0.0063 - val_loss: 0.0116 - val_mae: 0.0705 - learning_rate: 5.0000e-07
# Epoch 189/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1201e-04 - mae: 0.0062 - val_loss: 0.0116 - val_mae: 0.0708 - learning_rate: 5.0000e-07
# Epoch 190/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1195e-04 - mae: 0.0063 - val_loss: 0.0115 - val_mae: 0.0703 - learning_rate: 5.0000e-07
# Epoch 191/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.1461e-04 - mae: 0.0063 - val_loss: 0.0115 - val_mae: 0.0703 - learning_rate: 5.0000e-07
# Epoch 192/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0936e-04 - mae: 0.0062 - val_loss: 0.0115 - val_mae: 0.0702 - learning_rate: 5.0000e-07
# Epoch 193/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0794e-04 - mae: 0.0062 - val_loss: 0.0115 - val_mae: 0.0704 - learning_rate: 5.0000e-07
# Epoch 194/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0505e-04 - mae: 0.0061 - val_loss: 0.0114 - val_mae: 0.0700 - learning_rate: 5.0000e-07
# Epoch 195/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0532e-04 - mae: 0.0061 - val_loss: 0.0115 - val_mae: 0.0702 - learning_rate: 5.0000e-07
# Epoch 196/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0804e-04 - mae: 0.0062 - val_loss: 0.0115 - val_mae: 0.0701 - learning_rate: 5.0000e-07
# Epoch 197/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0138e-04 - mae: 0.0060 - val_loss: 0.0114 - val_mae: 0.0698 - learning_rate: 5.0000e-07
# Epoch 198/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0002e-04 - mae: 0.0060 - val_loss: 0.0114 - val_mae: 0.0698 - learning_rate: 5.0000e-07
# Epoch 199/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0337e-04 - mae: 0.0061 - val_loss: 0.0113 - val_mae: 0.0695 - learning_rate: 5.0000e-07
# Epoch 200/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.8024e-05 - mae: 0.0059 - val_loss: 0.0113 - val_mae: 0.0696 - learning_rate: 5.0000e-07
# Epoch 201/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.6670e-05 - mae: 0.0059 - val_loss: 0.0113 - val_mae: 0.0696 - learning_rate: 5.0000e-07
# Epoch 202/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.9678e-05 - mae: 0.0060 - val_loss: 0.0113 - val_mae: 0.0695 - learning_rate: 5.0000e-07
# Epoch 203/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.8700e-05 - mae: 0.0059 - val_loss: 0.0113 - val_mae: 0.0695 - learning_rate: 2.5000e-07
# Epoch 204/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0210e-04 - mae: 0.0060 - val_loss: 0.0112 - val_mae: 0.0693 - learning_rate: 2.5000e-07
# Epoch 205/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.5773e-05 - mae: 0.0059 - val_loss: 0.0113 - val_mae: 0.0693 - learning_rate: 2.5000e-07
# Epoch 206/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.8250e-05 - mae: 0.0059 - val_loss: 0.0112 - val_mae: 0.0691 - learning_rate: 2.5000e-07
# Epoch 207/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.8825e-05 - mae: 0.0060 - val_loss: 0.0112 - val_mae: 0.0694 - learning_rate: 2.5000e-07
# Epoch 208/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 8.9711e-05 - mae: 0.0057 - val_loss: 0.0112 - val_mae: 0.0691 - learning_rate: 2.5000e-07
# Epoch 209/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.6197e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0691 - learning_rate: 1.2500e-07
# Epoch 210/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.4996e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0691 - learning_rate: 1.2500e-07
# Epoch 211/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 9.6974e-05 - mae: 0.0059 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 1.2500e-07
# Epoch 212/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.1319e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0692 - learning_rate: 1.2500e-07
# Epoch 213/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.1107e-05 - mae: 0.0057 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 1.2500e-07
# Epoch 214/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.3497e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 1.2500e-07
# Epoch 215/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 1.0100e-04 - mae: 0.0060 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 6.2500e-08
# Epoch 216/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.2791e-05 - mae: 0.0057 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 6.2500e-08
# Epoch 217/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.5473e-05 - mae: 0.0057 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 6.2500e-08
# Epoch 218/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.3000e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 6.2500e-08
# Epoch 219/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.9618e-05 - mae: 0.0059 - val_loss: 0.0112 - val_mae: 0.0689 - learning_rate: 6.2500e-08
# Epoch 220/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.4289e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 3.1250e-08
# Epoch 221/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.4651e-05 - mae: 0.0058 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 3.1250e-08
# Epoch 222/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.2253e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0690 - learning_rate: 3.1250e-08
# Epoch 223/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.0025e-04 - mae: 0.0059 - val_loss: 0.0112 - val_mae: 0.0690 - learning_rate: 3.1250e-08
# Epoch 224/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.3755e-05 - mae: 0.0059 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 3.1250e-08
# Epoch 225/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 8.9549e-05 - mae: 0.0057 - val_loss: 0.0111 - val_mae: 0.0690 - learning_rate: 1.5625e-08
# Epoch 226/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.4399e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 1.5625e-08
# Epoch 227/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.2903e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 1.5625e-08
# Epoch 228/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 9.2868e-05 - mae: 0.0057 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 1.5625e-08
# Epoch 229/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 1.0067e-04 - mae: 0.0059 - val_loss: 0.0111 - val_mae: 0.0690 - learning_rate: 1.5625e-08
# Epoch 230/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 9.2006e-05 - mae: 0.0057 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 7.8125e-09
# Epoch 231/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.9540e-05 - mae: 0.0059 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 7.8125e-09
# Epoch 232/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 9.0986e-05 - mae: 0.0057 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 7.8125e-09
# Epoch 233/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 9.5307e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 7.8125e-09
# Epoch 234/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 9.3087e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 7.8125e-09
# Epoch 235/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 9.4665e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 3.9062e-09
# Epoch 236/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 9.2403e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 3.9062e-09
# Epoch 237/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.7676e-05 - mae: 0.0059 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 3.9062e-09
# Epoch 238/2000
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 9.3605e-05 - mae: 0.0058 - val_loss: 0.0111 - val_mae: 0.0689 - learning_rate: 3.9062e-09

# %%
# Guardando los parametros en la ejecucion 
parameters = {'topology': capas
              ,'data_normalized':True
              ,'puntos_entrenamiento':X_train.shape[0]
              ,'puntos_validacion':x_val.shape[0]
              ,'puntos_testeo':x_test.shape[0]
              #,'fn_activacion_por_capa':fn_activation_by_layer   # OJO, vamos a usar las funciones de activación por defecto
              ,'window_size':window_size
              ,'loss_metrics':loss_metric
              ,'model_metrics':model_metrics
              ,'epochs':epochs
              ,'batch_size':batch_size
              ,'optimizer':optimizer
              , 'scales' : scales}

mlflow.log_params(params=parameters
                  ,run_id=run_grandchild.info.run_id)

# %%
#Obteniendo las prediccciones del modelo
train_pred = model.predict(X_train)
val_pred = model.predict(x_val)
test_pred = model.predict(x_test)
# Out:
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
#df_clean.Close_Norm = scaler.inverse_transform(df_clean.Close_Norm.to_numpy().reshape(-1,1))

# %%
train_pred = scaler.inverse_transform(train_pred.reshape(-1,1)).reshape(-1)
val_pred = scaler.inverse_transform(val_pred.reshape(-1,1)).reshape(-1)
test_pred = scaler.inverse_transform(test_pred.reshape(-1,1)).reshape(-1)

# %%
train_test = {'train':train_pred,'test':test_pred}

fig = go.Figure()

dates = df['Close time_date']

date_train = dates[25:len(train_pred)]
date_val = dates[len(train_pred)+25:len(train_pred)+len(val_pred)+25]
date_test = dates[len(train_pred)+len(val_pred)+25:]


fig.add_trace(go.Scatter(x=dates
                            ,y=df.closex1M
                            ,mode='lines'
                            ,name='real'
                            ,line = dict(color='green')))

fig.add_trace(go.Scatter(x=date_train
                            ,y=train_pred.reshape(-1)
                            ,mode='lines'
                            ,name='train'   
                            ,line=dict(color='blue')))

fig.add_trace(go.Scatter(x=date_val
                            ,y=val_pred.reshape(-1)
                            ,mode='lines'
                            ,name='val'
                            ,line=dict(color='magenta')))

fig.add_trace(go.Scatter(x=date_test
                            ,y=test_pred.reshape(-1)
                            ,mode='lines'
                            ,name='test'
                            ,line= dict(color='red')))


fig.write_html(model_result_path)
    
fig.show()

# %%
#Guardando la imagen del resultado del modelo
mlflow.log_artifact(model_result_path,run_id=run_grandchild.info.run_id,artifact_path='resultados')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[385], line 2
#       1 #Guardando la imagen del resultado del modelo
# ----> 2 mlflow.log_artifact(model_result_path,run_id=run_grandchild.info.run_id,artifact_path='resultados')
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\mlflow\tracking\fluent.py:1179, in log_artifact(local_path, artifact_path, run_id)
#    1149 """
#    1150 Log a local file or directory as an artifact of the currently active run. If no run is
#    1151 active, this method will create a new active run.
#    (...)
#    1176             mlflow.log_artifact(path)
#    1177 """
#    1178 run_id = run_id or _get_or_start_run().info.run_id
# -> 1179 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\mlflow\tracking\client.py:1969, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1965 if run_id.startswith(TRACE_REQUEST_ID_PREFIX):
#    1966     raise MlflowException(
#    1967         f"Invalid run id: {run_id}. `log_artifact` run id must map to a valid run."
#    1968     )
# -> 1969 self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:842, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     840     artifact_repo.log_artifacts(local_path, path_name)
#     841 else:
# --> 842     artifact_repo.log_artifact(local_path, artifact_path)
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\mlflow\store\artifact\http_artifact_repo.py:63, in HttpArtifactRepository.log_artifact(self, local_file, artifact_path)
#      61 extra_headers = {"Content-Type": mime_type}
#      62 with open(local_file, "rb") as f:
# ---> 63     resp = http_request(
#      64         self._host_creds, endpoint, "PUT", data=f, extra_headers=extra_headers
#      65     )
#      66     augmented_raise_for_status(resp)
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\mlflow\utils\rest_utils.py:181, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, **kwargs)
#     178     kwargs["auth"] = fetch_auth(host_creds.auth)
#     180 try:
# --> 181     return _get_http_response_with_retries(
#     182         method,
#     183         url,
#     184         max_retries,
#     185         backoff_factor,
#     186         backoff_jitter,
#     187         retry_codes,
#     188         raise_on_status,
#     189         headers=headers,
#     190         verify=host_creds.verify,
#     191         timeout=timeout,
#     192         respect_retry_after_header=respect_retry_after_header,
#     193         **kwargs,
#     194     )
#     195 except requests.exceptions.Timeout as to:
#     196     raise MlflowException(
#     197         f"API request to {url} failed with timeout exception {to}."
#     198         " To increase the timeout, set the environment variable "
#     199         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     200     ) from to
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\mlflow\utils\request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     234 env_value = os.getenv("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File c:\Users\mefis\Desktop\MAESTRIA DE INTELIGENCIA ARTIFICIAL\TFM\ambiente_tfm\Lib\site-packages\urllib3\connection.py:459, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     457             self.send(b"%x\r\n%b\r\n" % (len(chunk), chunk))
#     458         else:
# --> 459             self.send(chunk)
#     461 # Regardless of whether we have a body or not, if we're in
#     462 # chunked mode we want to send an explicit empty chunk.
#     463 if chunked:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1055, in HTTPConnection.send(self, data)
#    1053 sys.audit("http.client.send", self, data)
#    1054 try:
# -> 1055     self.sock.sendall(data)
#    1056 except TypeError:
#    1057     if isinstance(data, collections.abc.Iterable):
#
# KeyboardInterrupt:

# %% [markdown]
# # Guardando metricas

# %%
mae_test = mean_absolute_error(y_true= scaler.inverse_transform(y_test.reshape(1, -1)), y_pred=test_pred.reshape(1, -1))
mae_train = mean_absolute_error(y_true= scaler.inverse_transform(y_train.reshape(1, -1)), y_pred=train_pred.reshape(1, -1))
mae_val = mean_absolute_error(y_true= scaler.inverse_transform(y_val.reshape(1, -1)), y_pred=val_pred.reshape(1, -1))


print(f"MAE train: {mae_train},   MAE val: {mae_val},  MAE test: {mae_test}")

metrics = {'mae_train':mae_train,'mae_val':mae_val,'mae_test':mae_test}
# Out:
# MAE train: 0.1559902156972694,   MAE val: 1.8512199934725317,  MAE test: 1.9569874201650206

# %%
mae_test = mean_absolute_error(y_true=y_test, y_pred=test_pred)
mae_train = mean_absolute_error(y_true=y_train, y_pred=train_pred)
mae_val = mean_absolute_error(y_true=y_val, y_pred=val_pred)


print(f"MAE train: {mae_train},   MAE val: {mae_val},  MAE test: {mae_test}")

metrics = {'mae_train':mae_train,'mae_val':mae_val,'mae_test':mae_test}
# Out:
# MAE train: 3.9427681579402885,   MAE val: 11.20865869436152,  MAE test: 13.741178217975321

# %%
mlflow.log_metrics(metrics=metrics,run_id=run_grandchild.info.run_id)

# %%
#mlflow.set_tags
